# %%
import os
import json
from dotenv import load_dotenv
import pandas as pd
import copy
import re
import time

from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# %%
# -----------------------------
#  Load Environment Variables
# -----------------------------
load_dotenv()
openai_key = os.getenv("OPENAI_API_KEY")

if not openai_key:
    raise ValueError("❌ OPENAI_API_KEY not found in .env file")


# -----------------------------
#  Initialize LLM (GPT-4o-mini)
# -----------------------------
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7, api_key=openai_key)
response = llm.invoke([HumanMessage(content="Generate a creative name for a toy car")])
print(response.content)
# Out:
# "Zoominator"

# %%
# -----------------------------
#  Define Agent State
# -----------------------------
class AgentState(dict):
    """Holds intermediate state during graph execution."""
    pass



# -----------------------------
#  Node: Load Excel
# -----------------------------
def load_excel(state: AgentState):
    df = pd.read_excel(state["input_path"])
    state["data"] = df
    return state

# %%
# Loading Input data:
input_data = f"data_cap.xlsx"
og_df = pd.read_excel(input_data)
print(f"Original data loaded: {len(og_df)} rows")

# Create a deep copy for transformations:
df = copy.deepcopy(og_df)
df.head()
# Out:
# Original data loaded: 73100 rows
#         Date Store ID Product ID     Category Region  Inventory Level  \
# 0 2022-01-01     S001      P0001    Groceries  North              231
# 1 2022-01-01     S001      P0002         Toys  South              204
# 2 2022-01-01     S001      P0003         Toys   West              102
# 3 2022-01-01     S001      P0004         Toys  North              469
# 4 2022-01-01     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# 1             Sunny                  0               66.16      Autumn
# 2             Sunny                  1               31.32      Summer
# 3            Cloudy                  1               34.74      Autumn
# 4             Sunny                  0               68.95      Summer

# %% [markdown]
# ## Updating Product IDs:

# %%
# -----------------------------------------------
#  Utility: Get Unique Categories
# -----------------------------------------------

def get_unique_categories(df, category_col="Category"):
    if category_col not in df.columns:
        raise ValueError(f"Column '{category_col}' not found in DataFrame.")
    unique_cats = sorted(df[category_col].dropna().unique().tolist())
    print(f"Found {len(unique_cats)} unique categories: {unique_cats}")
    return unique_cats



# -----------------------------------------------
#  Utility: Create Prefix Mapping
# -----------------------------------------------

def create_prefix_mapping(categories):
    mapping = {}
    used = set()

    for cat in categories:
        prefix = cat[0].upper()
        # Handle duplicate starting letters:
        if prefix in used:
            for ch in cat[1:].upper():
                if ch not in used and ch.isalpha():
                    prefix = ch
                    break
        used.add(prefix)
        mapping[cat] = prefix

    print("Category → Prefix mapping:")
    for k, v in mapping.items():
        print(f"   {k:15s} → {v}")
    return mapping


def save_prefix_mapping(mapping, path="category_prefix_map.json"):
    with open(path, "w") as f:
        json.dump(mapping, f, indent=4)
    print(f"Prefix mapping saved to {path}")


def load_prefix_mapping(path="category_prefix_map.json"):
    with open(path, "r") as f:
        mapping = json.load(f)
    print(f"Loaded prefix mapping from {path}")
    return mapping

# %%
# Creating the productid prefix map:
categories = get_unique_categories(df)
prefix_map = create_prefix_mapping(categories)
# Out:
# Found 5 unique categories: ['Clothing', 'Electronics', 'Furniture', 'Groceries', 'Toys']
# Category → Prefix mapping:
#    Clothing        → C
#    Electronics     → E
#    Furniture       → F
#    Groceries       → G
#    Toys            → T

# %%
# Mapping JSON path:
mapping_json_name = "category_prefix_map"
mapping_json_path = f"{mapping_json_name}.json"

# # Saving Mapping JSON:
# save_prefix_mapping(prefix_map, path=mapping_json_path)

# Loading Mapping JSON:
json_prefix_map = load_prefix_mapping(mapping_json_path)
json_prefix_map
# Out:
# Loaded prefix mapping from category_prefix_map.json
# {'Clothing': 'C',
#  'Electronics': 'E',
#  'Furniture': 'F',
#  'Groceries': 'G',
#  'Toys': 'T'}

# %%
# -----------------------------------------------
#  Utility: Saving df to xlsx
# -----------------------------------------------

def save_dataframe_to_xlsx(df, base_filename):
    output_path = f"{base_filename}.xlsx"
    df.to_excel(output_path, index=False)
    print(f"File saved successfully → {output_path}")
    return output_path



# -----------------------------------------------
#  Utility: Updating Product Ids
# -----------------------------------------------

def update_product_ids_in_df(df, prefix_mapping, output_path="input_data_with_new_pids"):

    # Generate new product IDs directly from df:
    def generate_new_id(row):
        old_id = str(row["Product ID"])
        category = row["Category"]
        prefix = prefix_mapping.get(category, "X")  # Default 'X' if not found
        return prefix + old_id[1:] if old_id else None

    # Create new column:
    df["New Product ID"] = df.apply(generate_new_id, axis=1)

    # Update original Product ID column:
    df["Product ID"] = df["New Product ID"]

    # Save updated DataFrame as new Excel:
    save_dataframe_to_xlsx(df, output_path)
    print(f"Product IDs updated and saved to {output_path}.xlsx")
    return df

# %%
# New data path:
new_data_name = "input_data_with_new_pids"
new_data_path = f"{new_data_name}"


# Update directly using the in-memory df:
updated_df = update_product_ids_in_df(df, prefix_map, output_path=new_data_path)
# Out:
# File saved successfully → input_data_with_new_pids.xlsx
# Product IDs updated and saved to input_data_with_new_pids.xlsx

# %%
updated_df.head()
# Out:
#         Date Store ID Product ID     Category Region  Inventory Level  \
# 0 2022-01-01     S001      G0001    Groceries  North              231
# 1 2022-01-01     S001      T0002         Toys  South              204
# 2 2022-01-01     S001      T0003         Toys   West              102
# 3 2022-01-01     S001      T0004         Toys  North              469
# 4 2022-01-01     S001      E0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality  \
# 0             Rainy                  0               29.69      Autumn
# 1             Sunny                  0               66.16      Autumn
# 2             Sunny                  1               31.32      Summer
# 3            Cloudy                  1               34.74      Autumn
# 4             Sunny                  0               68.95      Summer
#
#   New Product ID
# 0          G0001
# 1          T0002
# 2          T0003
# 3          T0004
# 4          E0005

# %% [markdown]
# ## Product name creation:

# %%
# Directly load the updated productid xlsx:
new_pid_data = f"input_data_with_new_pids.xlsx"
new_pid_df = pd.read_excel(new_pid_data)
print(f"new_pid_df data loaded: {len(new_pid_df)} rows")


# Create a deep copy for transformations:
df = copy.deepcopy(new_pid_df)
df.head()
# Out:
# new_pid_df data loaded: 73100 rows
#         Date Store ID Product ID     Category Region  Inventory Level  \
# 0 2022-01-01     S001      G0001    Groceries  North              231
# 1 2022-01-01     S001      T0002         Toys  South              204
# 2 2022-01-01     S001      T0003         Toys   West              102
# 3 2022-01-01     S001      T0004         Toys  North              469
# 4 2022-01-01     S001      E0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality  \
# 0             Rainy                  0               29.69      Autumn
# 1             Sunny                  0               66.16      Autumn
# 2             Sunny                  1               31.32      Summer
# 3            Cloudy                  1               34.74      Autumn
# 4             Sunny                  0               68.95      Summer
#
#   New Product ID
# 0          G0001
# 1          T0002
# 2          T0003
# 3          T0004
# 4          E0005

# %%
# ------------------------------------
#  Node: Gather Product specific rows
# ------------------------------------

# def gather_product_data(df, product_id):
#     sub_df = df[df["Product ID"] == product_id]
#     summary_lines = []
#     for _, row in sub_df.iterrows():
#         line = (
#             f"- Category: {row['Category']}, Region: {row['Region']}, "
#             f"Price: {row['Price']}, Discount: {row['Discount']}, "
#             f"Weather: {row['Weather Condition']}, Season: {row['Seasonality']}, "
#             f"Holiday/Promotion: {row['Holiday/Promotion']}, Demand Forecast: {row['Demand Forecast']}"
#         )
#         summary_lines.append(line)
    
#     summary_text = "\n".join(summary_lines)
#     return summary_text



def gather_product_data(df, product_id):
    """
    Summarizes the overall seasonal, weather, and holiday context 
    for a product by lightly aggregating its data across all stores and months.
    Returns a compact descriptive string.
    """
    # Normalize product ID
    df["Product ID"] = df["Product ID"].astype(str).str.strip().str.upper()
    product_id = str(product_id).strip().upper()

    # Filter for this product
    sub_df = df[df["Product ID"] == product_id].copy()
    if sub_df.empty:
        return ""

    # Get key context values
    category = sub_df["Category"].iloc[0]
    avg_price = round(sub_df["Price"].mean(), 2)
    avg_discount = round(sub_df["Discount"].mean(), 2)
    common_weather = sub_df["Weather Condition"].mode()[0]
    common_season = sub_df["Seasonality"].mode()[0]
    holiday_count = sub_df["Holiday/Promotion"].sum()
    regions = ", ".join(sub_df["Region"].unique())

    # Create a compact context string
    context = (
        f"Category: {category}, Avg Price: {avg_price}, Avg Discount: {avg_discount}%, "
        f"Common Weather: {common_weather}, Common Season: {common_season}, "
        f"Holiday/Promotion Frequency: {holiday_count}, Active Regions: {regions}."
    )
    return context

# %%
# -----------------------------
#  Node: Generate Product Names
# -----------------------------
# def generate_name(row):
#     prompt = f"""
#     You are a creative branding expert.

#     Create a **full product name** that includes:
#     1. What the item actually is (e.g., "wooden chair", "toy car", "LED lamp").
#     2. A creative or premium-sounding brand-style name.
#     3. Any relevant regional, weather, or seasonal context.
#     4. Holiday or promotion hints if applicable.

#     Data:
#     - Product ID: {row['Product ID']}
#     - Category: {row['Category']}
#     - Region: {row['Region']}
#     - Price: {row['Price']}
#     - Discount: {row['Discount']}
#     - Weather: {row['Weather Condition']}
#     - Season: {row['Seasonality']}
#     - Holiday/Promotion: {row['Holiday/Promotion']}

#     Output only the product name (no explanation).
#     """
#     result = llm.invoke([
#         SystemMessage(content="You are a creative marketing and branding assistant."),
#         HumanMessage(content=prompt)
#     ])
#     return result.content.strip()




def generate_name_for_product(product_id, category, product_data):
    """
    Generates a complete, market-ready product name that uniquely identifies
    a tangible product (not just its category), using all aggregated data.
    """
    prompt = f"""
    You are an expert product naming specialist working for a global retail brand.

    You will generate a **unique, object-specific product name** for Product ID {product_id}.
    The goal is to make it sound like a real, purchasable item — not a generic category or set.

    **Product Context:**
    {product_data}

    Create a **realistic, distinctive, and descriptive product name** that:
    1. Clearly identifies what the product actually is — a tangible object a person can buy,
       such as "wooden chess board", "foldable camping chair", "aroma diffuser lamp".
       Avoid generic classes like "set", "groceries", "furniture", or "electronics".
    2. Includes a creative or premium-sounding brand prefix, descriptor, or style element 
       (e.g., “AuroraCraft”, “LuxeGlow”, “HarvestBloom”).
    3. Optionally reflects the category "{category}" and contextual cues
       (season, weather, holidays, promotions, or regional traits).
    4. Feels authentic to modern branding — professional, elegant, concise, and memorable.
    5. Is **2–5 words long** and sounds like something seen in an online store or catalog.
    6. Avoid any vague or collective names ("set", "bundle", "pack", "groceries") unless it is a specific item name.
    7. Make the name sound **unique** — as if it belongs to one particular SKU or product variant.

    Output only the final product name — no explanations, no punctuation, no quotes.
    """

    result = llm.invoke([
        SystemMessage(content="You are a creative branding and product naming specialist."),
        HumanMessage(content=prompt)
    ])
    return result.content.strip()

# %%
# -------------------------------------
#  Node: Reflection for product name
# -------------------------------------
# def reflect_name(name, row, pass_num=1):
#     prompt = f"""
#     Reflection Pass {pass_num}:

#     The current product name is: "{name}"

#     Evaluate and improve it for:
#     - Creativity and emotional appeal
#     - Clarity of what the item actually is
#     - Fit for its category: {row['Category']}
#     - Relevance to region: {row['Region']}
#     - Price and discount context (affordable vs premium)
#     - Weather: {row['Weather Condition']}
#     - Seasonal relevance: {row['Seasonality']}
#     - Holiday or promotion theme: {row['Holiday/Promotion']}

#     Suggest ONE improved version (keep it realistic and marketable).
#     Output only the improved product name.
#     """
#     response = llm.invoke([HumanMessage(content=prompt)])
#     return response.content.strip()


def reflect_product_name(product_id, name, product_data, category, pass_num=1):
    """
    Refines and improves a previously generated product name,
    ensuring it describes a specific, tangible product rather than a generic type.
    """
    prompt = f"""
    Reflection Pass {pass_num}:

    Product ID: {product_id}
    Category: {category}
    Current product name: "{name}"

    **Product Context:**
    {product_data}

    Reflect on and refine this product name.

    Your goal is to improve it so that it:
    1. Describes a **specific physical product**, not a general type or collection.
       For example, "AuroraCraft Wooden Chess Board" is valid, but "Chess Set" or "Groceries" is not.
    2. Keeps brand realism — something that could appear in a store listing.
    3. Uses 2–5 words with a clear brand-style prefix, material, or feature (e.g., "Luxe", "Glow", "Forge", "Pure", "Flex").
    4. Incorporates contextual cues — seasonal, promotional, or regional if relevant — subtly, not explicitly.
    5. Sounds elegant, marketable, and memorable.
    6. Avoids vague, plural, or abstract phrasing ("set", "groceries", "furniture", "electronics").
    7. Stays concise, professional, and polished.

    Suggest ONE improved version that fulfills these conditions.

    Output only the final improved product name — no explanations or punctuation.
    """

    response = llm.invoke([HumanMessage(content=prompt)])
    return response.content.strip()

# %%
# -----------------------------------------------
#  Node: Reflection pipeline for multiple pass
# -----------------------------------------------

# def multiple_pass_reflection(row, num_passes=2):
#     name = generate_name(row)
#     print("Initial:", name)
#     for i in range(num_passes):
#         name = reflect_name(name, row, pass_num=i+1)
#         print(f"Reflection {i+1}:", name)
#     return name


def multiple_pass_reflection_by_product(df, num_passes=2, product_name_map=None, force_regenerate=False):
    """
    Generates and reflects product names for unique Product IDs,
    maintaining a persistent map of Product ID → Final Name.

    If a product already exists in the map and `force_regenerate=True`,
    or its cached name is empty/invalid, the name is recreated.
    """
    results = []
    unique_products = df["Product ID"].astype(str).str.strip().str.upper().unique()
    print(f"🧩 Found {len(unique_products)} unique products")

    # Initialize the cache if not provided
    if product_name_map is None:
        product_name_map = {}

    for pid in unique_products:
        pid_key = str(pid).strip().upper()
        category = df.loc[df["Product ID"].astype(str).str.strip().str.upper() == pid_key, "Category"].iloc[0]

        # Check if name already exists and is valid
        existing_name = product_name_map.get(pid_key, "").strip()
        should_regenerate = (
            force_regenerate or not existing_name or existing_name.lower() in ["", "nan", "none"]
        )

        if not should_regenerate:
            print(f"⚙️ Skipping {pid_key} — existing name: {existing_name}")
            results.append({
                "Product ID": pid_key,
                "Category": category,
                f"RefinedName_{num_passes}": existing_name
            })
            continue

        # 🧠 (Re)generate new name
        print(f"\n🔹 Processing Product ID: {pid_key} (Regenerate: {should_regenerate})")

        product_data = gather_product_data(df, pid_key)
        print(f"\n📘 product_data for {pid_key}:\n{product_data}\n")

        # Generate base name
        name = generate_name_for_product(pid_key, category, product_data)
        print("🪄 Initial Name:", name)

        # Multi-pass reflection
        for i in range(num_passes):
            name = reflect_product_name(pid_key, name, product_data, category, pass_num=i+1)
            print(f"💬 Reflection {i+1}:", name)

        final_name = name.strip()
        product_name_map[pid_key] = final_name  # ✅ Update the cache

        results.append({
            "Product ID": pid_key,
            "Category": category,
            f"RefinedName_{num_passes}": final_name
        })

    print(f"\n✅ Completed. Finalized names for {len(product_name_map)} products.\n")
    return pd.DataFrame(results), product_name_map

# %%
# -----------------------------------------------
#  Utility: Updating product names
# -----------------------------------------------


def assign_product_names_to_main_df(main_df, product_names_df):
    """
    Directly updates the main DataFrame by creating a new column 'Product Name'
    and assigning names based on Product ID lookups from product_names_df.

    Works without merging — row-by-row update using a map.
    """

    # Make a copy to avoid modifying original data
    df = main_df.copy()

    # --- Normalize Product IDs for consistency ---
    df["Product ID"] = df["Product ID"].astype(str).str.strip().str.upper()
    product_names_df["Product ID"] = product_names_df["Product ID"].astype(str).str.strip().str.upper()

    # --- Auto-detect final name column from reflection results ---
    name_cols = [col for col in product_names_df.columns if col.startswith("RefinedName_")]
    if not name_cols:
        raise ValueError("❌ No 'RefinedName_X' column found in product_names_df.")
    name_col = name_cols[-1]  # use the most recent reflection pass

    # --- Build Product ID → Name mapping dictionary ---
    name_map = dict(zip(product_names_df["Product ID"], product_names_df[name_col]))

    # --- Create new column and update values based on Product ID ---
    df["Product Name"] = df["Product ID"].map(name_map)

    # --- Debug summary ---
    filled = df["Product Name"].notna().sum()
    total = len(df)
    print(f" Assigned product names to {filled}/{total} rows using Product ID mapping.")
    print(f" New column added: 'Product Name'")

    return df

# %%
# Testing old pipeline:

# row = updated_df.iloc[0]
# print(row)

# #  Executing Reflection pipeline for product name creation:
# for i in range(3):
#     print(f"\n=== Row {i+1} ===")
#     prod_name = multiple_pass_reflection(updated_df.iloc[i])
#     print(f"Reflection row {i+1} prod_name:", prod_name)

# %%
# sub_df = df[df["Product ID"] == "T0003"]
# sub_df

s = gather_product_data(df, "T0003")

print(s)
# Out:
# Category: Toys, Avg Price: 55.95, Avg Discount: 10.27%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 373, Active Regions: West, East, South, North.

# %%
# Testing new pipeline:

# Generate new product names:
df_sample = df.head(3) # Subset your dataframe
product_names_df, prod_map_val = multiple_pass_reflection_by_product(df_sample, num_passes=2)
# product_names_df, prod_map_val = multiple_pass_reflection_by_product(df, num_passes=2)
# Out:
# 🧩 Found 100 unique products
#
# 🔹 Processing Product ID: G0001 (Regenerate: True)
#
# 📘 product_data for G0001:
# Category: Groceries, Avg Price: 55.81, Avg Discount: 10.35%, Common Weather: Cloudy, Common Season: Summer, Holiday/Promotion Frequency: 356, Active Regions: North, South, West, East.
#
# 🪄 Initial Name: HarvestEssence Cloudberry Jam
# 💬 Reflection 1: HarvestEssence Summer Cloudberry Preserve
# 💬 Reflection 2: HarvestEssence Summer Cloudberry Delight
#
# 🔹 Processing Product ID: T0002 (Regenerate: True)
#
# 📘 product_data for T0002:
# Category: Toys, Avg Price: 55.79, Avg Discount: 9.55%, Common Weather: Snowy, Common Season: Autumn, Holiday/Promotion Frequency: 350, Active Regions: South, West, North, East.
#
# 🪄 Initial Name: Snowy Adventure Plush Sled
# 💬 Reflection 1: Snowy Luxe Plush Sled
# 💬 Reflection 2: Snowy Luxe Plush Sledding Toy
#
# 🔹 Processing Product ID: T0003 (Regenerate: True)
#
# 📘 product_data for T0003:
# Category: Toys, Avg Price: 55.95, Avg Discount: 10.27%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 373, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: AutumnRain Adventure Puddle Jumpers
# 💬 Reflection 1: Rainy Day Splash Jumpers
# 💬 Reflection 2: Autumn Splash Jumper Boots
#
# 🔹 Processing Product ID: T0004 (Regenerate: True)
#
# 📘 product_data for T0004:
# Category: Toys, Avg Price: 57.24, Avg Discount: 9.94%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 359, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: SunnyQuest Adventure Kit
# 💬 Reflection 1: SunnyQuest Adventure Backpack
# 💬 Reflection 2: SunnyQuest Adventure Explorer Backpack
#
# 🔹 Processing Product ID: E0005 (Regenerate: True)
#
# 📘 product_data for E0005:
# Category: Electronics, Avg Price: 56.41, Avg Discount: 10.05%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 379, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: SunnyWave Bluetooth Speaker
# 💬 Reflection 1: SunnyWave Luxe Bluetooth Speaker
# 💬 Reflection 2: SunnyWave Luxe Winter Bluetooth Speaker
#
# 🔹 Processing Product ID: G0006 (Regenerate: True)
#
# 📘 product_data for G0006:
# Category: Groceries, Avg Price: 53.19, Avg Discount: 9.79%, Common Weather: Snowy, Common Season: Autumn, Holiday/Promotion Frequency: 400, Active Regions: South, North, East, West.
#
# 🪄 Initial Name: FrostHarvest Gourmet Soup Mix
# 💬 Reflection 1: FrostHarvest Artisan Soup Blend
# 💬 Reflection 2: FrostHarvest Gourmet Soup Medley
#
# 🔹 Processing Product ID: F0007 (Regenerate: True)
#
# 📘 product_data for F0007:
# Category: Furniture, Avg Price: 54.69, Avg Discount: 10.12%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 380, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: AutumnGlow Accent Chair
# 💬 Reflection 1: AutumnLuxe Accent Chair
# 💬 Reflection 2: AutumnLuxe Maple Accent Chair
#
# 🔹 Processing Product ID: C0008 (Regenerate: True)
#
# 📘 product_data for C0008:
# Category: Clothing, Avg Price: 53.73, Avg Discount: 10.34%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 359, Active Regions: North, East, South, West.
#
# 🪄 Initial Name: LuxeBreeze Summer Tunic
# 💬 Reflection 1: LuxeBreeze Summer Breeze Tunic
# 💬 Reflection 2: LuxeBreeze Sunlit Summer Tunic
#
# 🔹 Processing Product ID: E0009 (Regenerate: True)
#
# 📘 product_data for E0009:
# Category: Electronics, Avg Price: 53.54, Avg Discount: 9.93%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 356, Active Regions: West, North, South, East.
#
# 🪄 Initial Name: RainShield Wireless Earbuds
# 💬 Reflection 1: AutumnRain Luxe Wireless Earbuds
# 💬 Reflection 2: AutumnRain Luxe Bluetooth Earbuds
#
# 🔹 Processing Product ID: T0010 (Regenerate: True)
#
# 📘 product_data for T0010:
# Category: Toys, Avg Price: 56.02, Avg Discount: 10.18%, Common Weather: Snowy, Common Season: Autumn, Holiday/Promotion Frequency: 378, Active Regions: South, East, West, North.
#
# 🪄 Initial Name: FrostyPlay Snowball Maker
# 💬 Reflection 1: FrostyPlay Premium Snowball Maker
# 💬 Reflection 2: FrostyPlay Deluxe Snowball Maker
#
# 🔹 Processing Product ID: F0011 (Regenerate: True)
#
# 📘 product_data for F0011:
# Category: Furniture, Avg Price: 54.89, Avg Discount: 9.88%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 346, Active Regions: South, East, North, West.
#
# 🪄 Initial Name: SunnyNest Accent Table
# 💬 Reflection 1: SunnyNest Coastal Accent Table
# 💬 Reflection 2: SunnyNest Coastal Charm Accent Table
#
# 🔹 Processing Product ID: C0012 (Regenerate: True)
#
# 📘 product_data for C0012:
# Category: Clothing, Avg Price: 54.63, Avg Discount: 10.05%, Common Weather: Cloudy, Common Season: Winter, Holiday/Promotion Frequency: 391, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: Cloudspire Winter Wrap
# 💬 Reflection 1: Luxe Cloudspire Winter Wrap
# 💬 Reflection 2: Luxe Cloudspire Winter Wrap Coat
#
# 🔹 Processing Product ID: T0013 (Regenerate: True)
#
# 📘 product_data for T0013:
# Category: Toys, Avg Price: 55.81, Avg Discount: 10.32%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 376, Active Regions: South, North, East, West.
#
# 🪄 Initial Name: CloudySpring Adventure Kit
# 💬 Reflection 1: CloudySpring Explorer Kit
# 💬 Reflection 2: SpringCloud Adventure Kit
#
# 🔹 Processing Product ID: C0014 (Regenerate: True)
#
# 📘 product_data for C0014:
# Category: Clothing, Avg Price: 56.95, Avg Discount: 9.81%, Common Weather: Sunny, Common Season: Spring, Holiday/Promotion Frequency: 354, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: SunnySpring Linen Wrap Dress
# 💬 Reflection 1: LuxeSpring Linen Wrap Dress
# 💬 Reflection 2: LuxeSpring Eco Linen Wrap Dress
#
# 🔹 Processing Product ID: C0015 (Regenerate: True)
#
# 📘 product_data for C0015:
# Category: Clothing, Avg Price: 54.26, Avg Discount: 10.01%, Common Weather: Cloudy, Common Season: Summer, Holiday/Promotion Frequency: 355, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: CloudVista Summer Tunic
# 💬 Reflection 1: Luxe CloudVista Summer Tunic
# 💬 Reflection 2: Luxe CloudVista Breezy Tunic
#
# 🔹 Processing Product ID: E0016 (Regenerate: True)
#
# 📘 product_data for E0016:
# Category: Electronics, Avg Price: 54.89, Avg Discount: 10.28%, Common Weather: Snowy, Common Season: Summer, Holiday/Promotion Frequency: 341, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: FrostWave Portable Heater
# 💬 Reflection 1: FrostWave Luxe Compact Heater
# 💬 Reflection 2: FrostWave Luxe Ceramic Heater
#
# 🔹 Processing Product ID: T0017 (Regenerate: True)
#
# 📘 product_data for T0017:
# Category: Toys, Avg Price: 54.31, Avg Discount: 9.8%, Common Weather: Cloudy, Common Season: Summer, Holiday/Promotion Frequency: 369, Active Regions: West, South, North, East.
#
# 🪄 Initial Name: CloudySky Adventure Kite
# 💬 Reflection 1: NimbusPlay Skyhigh Kite
# 💬 Reflection 2: NimbusPlay CloudGlide Kite
#
# 🔹 Processing Product ID: C0018 (Regenerate: True)
#
# 📘 product_data for C0018:
# Category: Clothing, Avg Price: 55.36, Avg Discount: 10.31%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 375, Active Regions: South, West, North, East.
#
# 🪄 Initial Name: SnowSprout Fleece Pullover
# 💬 Reflection 1: SnowSprout Luxe Fleece Pullover
# 💬 Reflection 2: SnowSprout Luxe Fleece Pullover
#
# 🔹 Processing Product ID: C0019 (Regenerate: True)
#
# 📘 product_data for C0019:
# Category: Clothing, Avg Price: 56.37, Avg Discount: 10.07%, Common Weather: Cloudy, Common Season: Autumn, Holiday/Promotion Frequency: 375, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: AutumnCloud Knit Wrap
# 💬 Reflection 1: Luxe AutumnCloud Knit Wrap
# 💬 Reflection 2: Luxe AutumnCloud Cashmere Wrap
#
# 🔹 Processing Product ID: T0020 (Regenerate: True)
#
# 📘 product_data for T0020:
# Category: Toys, Avg Price: 55.79, Avg Discount: 9.73%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 390, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: SunnyHarvest Adventure Kite
# 💬 Reflection 1: SunnyHarvest Premium Adventure Kite
# 💬 Reflection 2: SunnyHarvest Luxe Adventure Kite
#
# 🔹 Processing Product ID: C0002 (Regenerate: True)
#
# 📘 product_data for C0002:
# Category: Clothing, Avg Price: 54.84, Avg Discount: 10.08%, Common Weather: Rainy, Common Season: Winter, Holiday/Promotion Frequency: 370, Active Regions: West, North, East, South.
#
# 🪄 Initial Name: Raindrop Shield Jacket
# 💬 Reflection 1: Luxe Raindrop Shield Jacket
# 💬 Reflection 2: Luxe Winter Raindrop Shield Jacket
#
# 🔹 Processing Product ID: F0003 (Regenerate: True)
#
# 📘 product_data for F0003:
# Category: Furniture, Avg Price: 54.4, Avg Discount: 9.75%, Common Weather: Snowy, Common Season: Winter, Holiday/Promotion Frequency: 363, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: Frosted Birch Accent Table
# 💬 Reflection 1: WinterGlow Frosted Birch Accent Table
# 💬 Reflection 2: Frosted Birch WinterGlow Accent Table
#
# 🔹 Processing Product ID: T0005 (Regenerate: True)
#
# 📘 product_data for T0005:
# Category: Toys, Avg Price: 55.04, Avg Discount: 9.69%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 389, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: Autumn Raindrop Playset
# 💬 Reflection 1: Raindrop Elegance Playset
# 💬 Reflection 2: Raindrop Luxe Playset
#
# 🔹 Processing Product ID: F0006 (Regenerate: True)
#
# 📘 product_data for F0006:
# Category: Furniture, Avg Price: 55.2, Avg Discount: 10.03%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 348, Active Regions: North, East, South, West.
#
# 🪄 Initial Name: HarvestNest Lounge Chair
# 💬 Reflection 1: HarvestNest Autumn Lounge Chair
# 💬 Reflection 2: AmberGlow Autumn Lounge Chair
#
# 🔹 Processing Product ID: G0007 (Regenerate: True)
#
# 📘 product_data for G0007:
# Category: Groceries, Avg Price: 54.69, Avg Discount: 10.11%, Common Weather: Snowy, Common Season: Summer, Holiday/Promotion Frequency: 368, Active Regions: West, North, South, East.
#
# 🪄 Initial Name: FrostyHarvest Gourmet Soup Mix
# 💬 Reflection 1: FrostyHarvest Winter Comfort Soup Mix
# 💬 Reflection 2: FrostyHarvest Seasonal Comfort Soup Mix
#
# 🔹 Processing Product ID: E0008 (Regenerate: True)
#
# 📘 product_data for E0008:
# Category: Electronics, Avg Price: 55.79, Avg Discount: 9.94%, Common Weather: Rainy, Common Season: Summer, Holiday/Promotion Frequency: 379, Active Regions: West, North, East, South.
#
# 🪄 Initial Name: AquaShield Bluetooth Umbrella
# 💬 Reflection 1: AquaShield Summer Bluetooth Umbrella
# 💬 Reflection 2: AquaShield Summer Breeze Bluetooth Umbrella
#
# 🔹 Processing Product ID: C0009 (Regenerate: True)
#
# 📘 product_data for C0009:
# Category: Clothing, Avg Price: 56.07, Avg Discount: 10.52%, Common Weather: Rainy, Common Season: Spring, Holiday/Promotion Frequency: 374, Active Regions: South, West, North, East.
#
# 🪄 Initial Name: RainGuard Luxe Jacket
# 💬 Reflection 1: RainGuard Luxe Waterproof Jacket
# 💬 Reflection 2: RainGuard Luxe Spring Waterproof Jacket
#
# 🔹 Processing Product ID: E0010 (Regenerate: True)
#
# 📘 product_data for E0010:
# Category: Electronics, Avg Price: 54.79, Avg Discount: 9.9%, Common Weather: Snowy, Common Season: Winter, Holiday/Promotion Frequency: 375, Active Regions: North, West, East, South.
#
# 🪄 Initial Name: FrostGlow Smart Heater
# 💬 Reflection 1: WinterGlow Smart Heater
# 💬 Reflection 2: WinterGlow Luxe Heater
#
# 🔹 Processing Product ID: G0011 (Regenerate: True)
#
# 📘 product_data for G0011:
# Category: Groceries, Avg Price: 57.81, Avg Discount: 9.69%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 353, Active Regions: West, East, North, South.
#
# 🪄 Initial Name: FrostyHarvest Artisan Soup Mix
# 💬 Reflection 1: SnowyHarvest Gourmet Soup Blend
# 💬 Reflection 2: SnowyHarvest Artisan Soup Mix
#
# 🔹 Processing Product ID: G0012 (Regenerate: True)
#
# 📘 product_data for G0012:
# Category: Groceries, Avg Price: 55.39, Avg Discount: 9.79%, Common Weather: Sunny, Common Season: Spring, Holiday/Promotion Frequency: 360, Active Regions: East, West, South, North.
#
# 🪄 Initial Name: SunnyHarvest Citrus Zest Oil
# 💬 Reflection 1: SunnyHarvest Zesty Citrus Infusion
# 💬 Reflection 2: SunnyHarvest Citrus Splash Infusion
#
# 🔹 Processing Product ID: C0013 (Regenerate: True)
#
# 📘 product_data for C0013:
# Category: Clothing, Avg Price: 53.78, Avg Discount: 9.82%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 355, Active Regions: East, West, South, North.
#
# 🪄 Initial Name: SunnyWool Winter Wrap
# 💬 Reflection 1: LuxeSunny Wool Wrap
# 💬 Reflection 2: LuxeSunny Winter Wool Wrap
#
# 🔹 Processing Product ID: E0014 (Regenerate: True)
#
# 📘 product_data for E0014:
# Category: Electronics, Avg Price: 56.62, Avg Discount: 10.03%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 359, Active Regions: East, South, West, North.
#
# 🪄 Initial Name: NimbusWave Bluetooth Speaker
# 💬 Reflection 1: NimbusWave Spring Breeze Bluetooth Speaker
# 💬 Reflection 2: NimbusWave Spring Breeze Portable Bluetooth Speaker
#
# 🔹 Processing Product ID: T0015 (Regenerate: True)
#
# 📘 product_data for T0015:
# Category: Toys, Avg Price: 55.3, Avg Discount: 9.91%, Common Weather: Rainy, Common Season: Winter, Holiday/Promotion Frequency: 332, Active Regions: South, North, West, East.
#
# 🪄 Initial Name: WinterWonder Playhouse
# 💬 Reflection 1: CozyHaven Winter Playhouse
# 💬 Reflection 2: CozyHaven Winter Wonderland Playhouse
#
# 🔹 Processing Product ID: T0016 (Regenerate: True)
#
# 📘 product_data for T0016:
# Category: Toys, Avg Price: 54.72, Avg Discount: 10.22%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 345, Active Regions: South, West, North, East.
#
# 🪄 Initial Name: SunnySprout Adventure Kite
# 💬 Reflection 1: SunnySprout Premium Kite
# 💬 Reflection 2: SunnySprout Eco-Friendly Kite
#
# 🔹 Processing Product ID: G0017 (Regenerate: True)
#
# 📘 product_data for G0017:
# Category: Groceries, Avg Price: 56.06, Avg Discount: 9.97%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 344, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: HarvestGlow Autumn Spice Blend
# 💬 Reflection 1: HarvestGlow Autumn Spice Medley
# 💬 Reflection 2: HarvestGlow Autumn Spice Blend
#
# 🔹 Processing Product ID: G0018 (Regenerate: True)
#
# 📘 product_data for G0018:
# Category: Groceries, Avg Price: 55.14, Avg Discount: 10.19%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 383, Active Regions: North, West, East, South.
#
# 🪄 Initial Name: SunnyHarvest Fruit Medley
# 💬 Reflection 1: SunnyHarvest Tropical Bliss Medley
# 💬 Reflection 2: SunnyHarvest Tropical Bliss Fruit Medley
#
# 🔹 Processing Product ID: T0019 (Regenerate: True)
#
# 📘 product_data for T0019:
# Category: Toys, Avg Price: 55.16, Avg Discount: 10.09%, Common Weather: Cloudy, Common Season: Summer, Holiday/Promotion Frequency: 372, Active Regions: East, North, West, South.
#
# 🪄 Initial Name: CloudPlay Adventure Kit
# 💬 Reflection 1: CloudPlay Summer Adventure Kit
# 💬 Reflection 2: CloudPlay Adventure Splash Kit
#
# 🔹 Processing Product ID: T0001 (Regenerate: True)
#
# 📘 product_data for T0001:
# Category: Toys, Avg Price: 54.73, Avg Discount: 10.27%, Common Weather: Cloudy, Common Season: Winter, Holiday/Promotion Frequency: 347, Active Regions: South, West, North, East.
#
# 🪄 Initial Name: CloudyCove Snowfall Playset
# 💬 Reflection 1: Snowfall Dreamscape Playset
# 💬 Reflection 2: WinterGlow Snowfall Playset
#
# 🔹 Processing Product ID: E0002 (Regenerate: True)
#
# 📘 product_data for E0002:
# Category: Electronics, Avg Price: 56.2, Avg Discount: 9.74%, Common Weather: Rainy, Common Season: Summer, Holiday/Promotion Frequency: 381, Active Regions: West, East, North, South.
#
# 🪄 Initial Name: AquaShield Portable Charger
# 💬 Reflection 1: AquaShield Luxe Rain-Ready Charger
# 💬 Reflection 2: AquaShield Luxe Rain-Guard Charger
#
# 🔹 Processing Product ID: G0003 (Regenerate: True)
#
# 📘 product_data for G0003:
# Category: Groceries, Avg Price: 55.3, Avg Discount: 9.78%, Common Weather: Snowy, Common Season: Summer, Holiday/Promotion Frequency: 374, Active Regions: South, West, East, North.
#
# 🪄 Initial Name: FrostyHarvest Fruit Medley
# 💬 Reflection 1: FrostyHarvest Summer Berry Blend
# 💬 Reflection 2: FrostyHarvest Summer Berry Medley
#
# 🔹 Processing Product ID: C0005 (Regenerate: True)
#
# 📘 product_data for C0005:
# Category: Clothing, Avg Price: 55.05, Avg Discount: 9.71%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 340, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: FrostGuard Parka
# 💬 Reflection 1: FrostGuard Luxe Parka
# 💬 Reflection 2: FrostGuard Elite Winter Parka
#
# 🔹 Processing Product ID: E0007 (Regenerate: True)
#
# 📘 product_data for E0007:
# Category: Electronics, Avg Price: 54.78, Avg Discount: 9.97%, Common Weather: Cloudy, Common Season: Winter, Holiday/Promotion Frequency: 368, Active Regions: North, West, East, South.
#
# 🪄 Initial Name: NimbusWave Portable Heater
# 💬 Reflection 1: NimbusWave Winter Radiant Heater
# 💬 Reflection 2: NimbusWave WinterGlow Heater
#
# 🔹 Processing Product ID: T0008 (Regenerate: True)
#
# 📘 product_data for T0008:
# Category: Toys, Avg Price: 55.16, Avg Discount: 10.13%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 350, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: SunnyWhims Adventure Castle
# 💬 Reflection 1: SunnyWhims Enchanted Castle Playset
# 💬 Reflection 2: SunnyWhims Winter Enchanted Castle Playset
#
# 🔹 Processing Product ID: G0009 (Regenerate: True)
#
# 📘 product_data for G0009:
# Category: Groceries, Avg Price: 57.63, Avg Discount: 10.43%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 360, Active Regions: South, West, North, East.
#
# 🪄 Initial Name: HarvestNest Organic Quinoa
# 💬 Reflection 1: HarvestNest Pure Organic Quinoa
# 💬 Reflection 2: HarvestNest Spring Essence Organic Quinoa
#
# 🔹 Processing Product ID: G0010 (Regenerate: True)
#
# 📘 product_data for G0010:
# Category: Groceries, Avg Price: 56.45, Avg Discount: 9.95%, Common Weather: Cloudy, Common Season: Autumn, Holiday/Promotion Frequency: 381, Active Regions: South, East, West, North.
#
# 🪄 Initial Name: HarvestCrate Artisan Apples
# 💬 Reflection 1: HarvestCrate Autumn Apples
# 💬 Reflection 2: AutumnHarvest Crisp Apples
#
# 🔹 Processing Product ID: T0011 (Regenerate: True)
#
# 📘 product_data for T0011:
# Category: Toys, Avg Price: 55.63, Avg Discount: 9.68%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 366, Active Regions: East, South, North, West.
#
# 🪄 Initial Name: SunnyPlay Adventure Kit
# 💬 Reflection 1: SunnyPlay Autumn Adventure Kit
# 💬 Reflection 2: SunnyPlay Autumn Explorer Kit
#
# 🔹 Processing Product ID: E0012 (Regenerate: True)
#
# 📘 product_data for E0012:
# Category: Electronics, Avg Price: 54.94, Avg Discount: 10.48%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 322, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: FrostGuard Wireless Heater
# 💬 Reflection 1: FrostGuard Luxe Heater
# 💬 Reflection 2: FrostGuard Luxe Radiant Heater
#
# 🔹 Processing Product ID: F0013 (Regenerate: True)
#
# 📘 product_data for F0013:
# Category: Furniture, Avg Price: 54.04, Avg Discount: 10.18%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 364, Active Regions: North, East, South, West.
#
# 🪄 Initial Name: NimbusNest Lounge Chair
# 💬 Reflection 1: NimbusNest Cloud Lounge Chair
# 💬 Reflection 2: NimbusNest Luxe Cloud Lounge Chair
#
# 🔹 Processing Product ID: G0016 (Regenerate: True)
#
# 📘 product_data for G0016:
# Category: Groceries, Avg Price: 53.34, Avg Discount: 9.92%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 385, Active Regions: South, East, North, West.
#
# 🪄 Initial Name: Frosted Citrus Medley
# 💬 Reflection 1: Frosted Citrus Delight
# 💬 Reflection 2: Citrus Frosted Bliss Bites
#
# 🔹 Processing Product ID: C0017 (Regenerate: True)
#
# 📘 product_data for C0017:
# Category: Clothing, Avg Price: 53.33, Avg Discount: 10.15%, Common Weather: Rainy, Common Season: Winter, Holiday/Promotion Frequency: 378, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: LuxeRain Overcoat
# 💬 Reflection 1: LuxeRain Winter Overcoat
# 💬 Reflection 2: LuxeRain Classic Trench Overcoat
#
# 🔹 Processing Product ID: T0018 (Regenerate: True)
#
# 📘 product_data for T0018:
# Category: Toys, Avg Price: 53.65, Avg Discount: 10.01%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 315, Active Regions: West, North, East, South.
#
# 🪄 Initial Name: SunnySnow Adventure Kit
# 💬 Reflection 1: SunnyGlow Winter Adventure Kit
# 💬 Reflection 2: SunnyGlow Winter Wonderland Adventure Kit
#
# 🔹 Processing Product ID: E0020 (Regenerate: True)
#
# 📘 product_data for E0020:
# Category: Electronics, Avg Price: 55.59, Avg Discount: 9.99%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 363, Active Regions: North, South, East, West.
#
# 🪄 Initial Name: NimbusCharge Wireless Power Bank
# 💬 Reflection 1: NimbusCharge SpringFlex Wireless Power Bank
# 💬 Reflection 2: NimbusCharge CloudFlex Wireless Power Bank
#
# 🔹 Processing Product ID: C0003 (Regenerate: True)
#
# 📘 product_data for C0003:
# Category: Clothing, Avg Price: 54.82, Avg Discount: 9.6%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 351, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: SunnyNest Autumn Wrap
# 💬 Reflection 1: SunnyNest Luxe Autumn Wrap
# 💬 Reflection 2: SunnyNest Luxe Autumn Wrap Scarf
#
# 🔹 Processing Product ID: G0004 (Regenerate: True)
#
# 📘 product_data for G0004:
# Category: Groceries, Avg Price: 55.78, Avg Discount: 9.99%, Common Weather: Snowy, Common Season: Summer, Holiday/Promotion Frequency: 355, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: FrostyHarvest Citrus Medley
# 💬 Reflection 1: FrostyHarvest Summer Citrus Blend
# 💬 Reflection 2: FrostyHarvest Summer Citrus Splash
#
# 🔹 Processing Product ID: G0005 (Regenerate: True)
#
# 📘 product_data for G0005:
# Category: Groceries, Avg Price: 53.1, Avg Discount: 9.46%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 396, Active Regions: North, West, East, South.
#
# 🪄 Initial Name: HarvestEssence Spiced Pumpkin Soup
# 💬 Reflection 1: HarvestEssence Autumn Spiced Pumpkin Soup
# 💬 Reflection 2: HarvestEssence Spiced Pumpkin Velvet Soup
#
# 🔹 Processing Product ID: E0006 (Regenerate: True)
#
# 📘 product_data for E0006:
# Category: Electronics, Avg Price: 55.29, Avg Discount: 10.23%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 340, Active Regions: East, North, South, West.
#
# 🪄 Initial Name: NimbusSound Wireless Speaker
# 💬 Reflection 1: NimbusSound CloudFlex Wireless Speaker
# 💬 Reflection 2: NimbusSound CloudFlex Spring Speaker
#
# 🔹 Processing Product ID: F0008 (Regenerate: True)
#
# 📘 product_data for F0008:
# Category: Furniture, Avg Price: 55.72, Avg Discount: 10.21%, Common Weather: Rainy, Common Season: Spring, Holiday/Promotion Frequency: 373, Active Regions: South, East, West, North.
#
# 🪄 Initial Name: RainBloom Patio Lounge Chair
# 💬 Reflection 1: LuxeRain Patio Lounge Chair
# 💬 Reflection 2: LuxeRain Spring Patio Lounge Chair
#
# 🔹 Processing Product ID: F0009 (Regenerate: True)
#
# 📘 product_data for F0009:
# Category: Furniture, Avg Price: 54.73, Avg Discount: 10.01%, Common Weather: Cloudy, Common Season: Summer, Holiday/Promotion Frequency: 373, Active Regions: North, South, West, East.
#
# 🪄 Initial Name: NimbusNest Lounge Chair
# 💬 Reflection 1: NimbusNest Cloud Lounge Chair
# 💬 Reflection 2: NimbusNest Cloud Comfort Chair
#
# 🔹 Processing Product ID: E0011 (Regenerate: True)
#
# 📘 product_data for E0011:
# Category: Electronics, Avg Price: 57.88, Avg Discount: 9.49%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 382, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: SunnyWave Bluetooth Speaker
# 💬 Reflection 1: SunnyWave Summer Bluetooth Speaker
# 💬 Reflection 2: SunnyWave Breeze Bluetooth Speaker
#
# 🔹 Processing Product ID: E0017 (Regenerate: True)
#
# 📘 product_data for E0017:
# Category: Electronics, Avg Price: 54.54, Avg Discount: 9.82%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 361, Active Regions: South, East, West, North.
#
# 🪄 Initial Name: SolarSync Bluetooth Speaker
# 💬 Reflection 1: LuxeSolar Sync Bluetooth Speaker
# 💬 Reflection 2: LuxeSolar Autumn Breeze Bluetooth Speaker
#
# 🔹 Processing Product ID: G0019 (Regenerate: True)
#
# 📘 product_data for G0019:
# Category: Groceries, Avg Price: 55.57, Avg Discount: 9.82%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 348, Active Regions: West, South, North, East.
#
# 🪄 Initial Name: SunnyHarvest Citrus Medley
# 💬 Reflection 1: SunnyHarvest Summer Citrus Splash
# 💬 Reflection 2: SunnyHarvest Citrus Refresh
#
# 🔹 Processing Product ID: C0020 (Regenerate: True)
#
# 📘 product_data for C0020:
# Category: Clothing, Avg Price: 54.55, Avg Discount: 9.78%, Common Weather: Snowy, Common Season: Autumn, Holiday/Promotion Frequency: 352, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: FrostGuard Thermal Jacket
# 💬 Reflection 1: FrostGuard Luxe Thermal Jacket
# 💬 Reflection 2: SnowGuard Luxe Thermal Coat
#
# 🔹 Processing Product ID: E0003 (Regenerate: True)
#
# 📘 product_data for E0003:
# Category: Electronics, Avg Price: 53.84, Avg Discount: 10.09%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 337, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: SunnyTech Portable Bluetooth Speaker
# 💬 Reflection 1: SunnyTech Summer Breeze Bluetooth Speaker
# 💬 Reflection 2: SunnyTech BreezeGlow Portable Speaker
#
# 🔹 Processing Product ID: F0004 (Regenerate: True)
#
# 📘 product_data for F0004:
# Category: Furniture, Avg Price: 54.76, Avg Discount: 9.76%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 383, Active Regions: West, North, East, South.
#
# 🪄 Initial Name: SunnyNest Accent Chair
# 💬 Reflection 1: SunnyNest Luxe Winter Accent Chair
# 💬 Reflection 2: SunnyNest Luxe Winter Retreat Chair
#
# 🔹 Processing Product ID: C0007 (Regenerate: True)
#
# 📘 product_data for C0007:
# Category: Clothing, Avg Price: 56.72, Avg Discount: 10.28%, Common Weather: Cloudy, Common Season: Summer, Holiday/Promotion Frequency: 364, Active Regions: South, East, West, North.
#
# 🪄 Initial Name: CloudBreeze Summer Tunic
# 💬 Reflection 1: LuxeCloud Summer Tunic
# 💬 Reflection 2: LuxeCloud Breezy Summer Tunic
#
# 🔹 Processing Product ID: C0010 (Regenerate: True)
#
# 📘 product_data for C0010:
# Category: Clothing, Avg Price: 53.2, Avg Discount: 10.25%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 341, Active Regions: East, North, West, South.
#
# 🪄 Initial Name: AutumnWoven Cardigan
# 💬 Reflection 1: Luxe Autumn Woven Cardigan
# 💬 Reflection 2: Luxe Cozy Autumn Cardigan
#
# 🔹 Processing Product ID: F0015 (Regenerate: True)
#
# 📘 product_data for F0015:
# Category: Furniture, Avg Price: 54.75, Avg Discount: 10.14%, Common Weather: Cloudy, Common Season: Autumn, Holiday/Promotion Frequency: 379, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: HarvestHaven Accent Table
# 💬 Reflection 1: AutumnGlow Rustic Accent Table
# 💬 Reflection 2: AutumnGlow Rustic Side Table
#
# 🔹 Processing Product ID: C0016 (Regenerate: True)
#
# 📘 product_data for C0016:
# Category: Clothing, Avg Price: 55.51, Avg Discount: 9.76%, Common Weather: Rainy, Common Season: Winter, Holiday/Promotion Frequency: 363, Active Regions: South, West, East, North.
#
# 🪄 Initial Name: RainGuard Luxe Anorak
# 💬 Reflection 1: RainGuard Luxe Waterproof Anorak
# 💬 Reflection 2: RainGuard Luxe Winter Anorak
#
# 🔹 Processing Product ID: F0018 (Regenerate: True)
#
# 📘 product_data for F0018:
# Category: Furniture, Avg Price: 54.23, Avg Discount: 10.29%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 361, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: Frosted Maple Accent Table
# 💬 Reflection 1: Luxe Frosted Maple Accent Table
# 💬 Reflection 2: Luxe Frosted Maple Side Table
#
# 🔹 Processing Product ID: T0009 (Regenerate: True)
#
# 📘 product_data for T0009:
# Category: Toys, Avg Price: 53.68, Avg Discount: 10.18%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 364, Active Regions: South, East, West, North.
#
# 🪄 Initial Name: CloudSprout Playhouse
# 💬 Reflection 1: SpringBloom CloudSprout Playhouse
# 💬 Reflection 2: SpringBreeze CloudSprout Playhouse
#
# 🔹 Processing Product ID: F0012 (Regenerate: True)
#
# 📘 product_data for F0012:
# Category: Furniture, Avg Price: 57.02, Avg Discount: 9.81%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 361, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: Autumn Haven Accent Chair
# 💬 Reflection 1: Autumn Luxe Accent Chair
# 💬 Reflection 2: Autumn Luxe Rain-Resistant Accent Chair
#
# 🔹 Processing Product ID: E0015 (Regenerate: True)
#
# 📘 product_data for E0015:
# Category: Electronics, Avg Price: 54.21, Avg Discount: 9.76%, Common Weather: Cloudy, Common Season: Winter, Holiday/Promotion Frequency: 348, Active Regions: East, South, West, North.
#
# 🪄 Initial Name: NimbusWave Smart Heater
# 💬 Reflection 1: NimbusWave WinterSmart Heater
# 💬 Reflection 2: NimbusWave CozyHeat Radiator
#
# 🔹 Processing Product ID: F0017 (Regenerate: True)
#
# 📘 product_data for F0017:
# Category: Furniture, Avg Price: 55.02, Avg Discount: 10.25%, Common Weather: Sunny, Common Season: Summer, Holiday/Promotion Frequency: 381, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: SunnyNest Lounge Chair
# 💬 Reflection 1: SunnyNest Luxe Lounge Chair
# 💬 Reflection 2: SunnyNest Luxe Summer Lounge Chair
#
# 🔹 Processing Product ID: F0019 (Regenerate: True)
#
# 📘 product_data for F0019:
# Category: Furniture, Avg Price: 54.68, Avg Discount: 9.92%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 381, Active Regions: South, North, East, West.
#
# 🪄 Initial Name: AutumnRain Lounge Chair
# 💬 Reflection 1: AutumnRain Luxe Lounge Chair
# 💬 Reflection 2: AutumnRain Luxe Armchair
#
# 🔹 Processing Product ID: E0001 (Regenerate: True)
#
# 📘 product_data for E0001:
# Category: Electronics, Avg Price: 54.6, Avg Discount: 10.31%, Common Weather: Cloudy, Common Season: Winter, Holiday/Promotion Frequency: 352, Active Regions: West, North, East, South.
#
# 🪄 Initial Name: NimbusWave Smart Heater
# 💬 Reflection 1: NimbusWave Winter Smart Heater
# 💬 Reflection 2: NimbusWave Luxe Winter Heater
#
# 🔹 Processing Product ID: F0002 (Regenerate: True)
#
# 📘 product_data for F0002:
# Category: Furniture, Avg Price: 54.84, Avg Discount: 10.15%, Common Weather: Rainy, Common Season: Spring, Holiday/Promotion Frequency: 374, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: RainySpring Armchair
# 💬 Reflection 1: Luxe RainySpring Accent Chair
# 💬 Reflection 2: Luxe RainySpring Chair
#
# 🔹 Processing Product ID: T0012 (Regenerate: True)
#
# 📘 product_data for T0012:
# Category: Toys, Avg Price: 52.8, Avg Discount: 9.63%, Common Weather: Snowy, Common Season: Summer, Holiday/Promotion Frequency: 340, Active Regions: North, West, East, South.
#
# 🪄 Initial Name: FrostyPlay Snowball Launchers
# 💬 Reflection 1: FrostyPlay Snowball Blaster
# 💬 Reflection 2: FrostyPlay Premium Snowball Launcher
#
# 🔹 Processing Product ID: F0014 (Regenerate: True)
#
# 📘 product_data for F0014:
# Category: Furniture, Avg Price: 55.42, Avg Discount: 9.82%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 386, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: CloudNest Lounge Chair
# 💬 Reflection 1: LuxeCloud Spring Lounge Chair
# 💬 Reflection 2: LuxeCloud Springtime Lounge Chair
#
# 🔹 Processing Product ID: G0002 (Regenerate: True)
#
# 📘 product_data for G0002:
# Category: Groceries, Avg Price: 54.69, Avg Discount: 10.06%, Common Weather: Rainy, Common Season: Summer, Holiday/Promotion Frequency: 364, Active Regions: East, North, West, South.
#
# 🪄 Initial Name: RainyDay Gourmet Soup Mix
# 💬 Reflection 1: RainyDay Artisan Soup Blend
# 💬 Reflection 2: RainyDay Gourmet Soup Blend
#
# 🔹 Processing Product ID: F0005 (Regenerate: True)
#
# 📘 product_data for F0005:
# Category: Furniture, Avg Price: 55.55, Avg Discount: 10.43%, Common Weather: Sunny, Common Season: Spring, Holiday/Promotion Frequency: 349, Active Regions: East, West, North, South.
#
# 🪄 Initial Name: SunnySpring Lounge Chair
# 💬 Reflection 1: SunnySpring Luxe Lounge Chair
# 💬 Reflection 2: SunnySpring Luxe Relaxation Chair
#
# 🔹 Processing Product ID: F0010 (Regenerate: True)
#
# 📘 product_data for F0010:
# Category: Furniture, Avg Price: 56.28, Avg Discount: 9.98%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 364, Active Regions: West, South, East, North.
#
# 🪄 Initial Name: SunnyNest Lounge Chair
# 💬 Reflection 1: SunnyNest Luxe Lounge Chair
# 💬 Reflection 2: SunnyNest Luxe Winter Lounge Chair
#
# 🔹 Processing Product ID: E0013 (Regenerate: True)
#
# 📘 product_data for E0013:
# Category: Electronics, Avg Price: 56.51, Avg Discount: 9.97%, Common Weather: Rainy, Common Season: Winter, Holiday/Promotion Frequency: 338, Active Regions: West, East, South, North.
#
# 🪄 Initial Name: RainGuard Smart Umbrella
# 💬 Reflection 1: LuxeRain Shield Umbrella
# 💬 Reflection 2: LuxeRain Premium Umbrella
#
# 🔹 Processing Product ID: T0014 (Regenerate: True)
#
# 📘 product_data for T0014:
# Category: Toys, Avg Price: 55.21, Avg Discount: 9.99%, Common Weather: Snowy, Common Season: Winter, Holiday/Promotion Frequency: 383, Active Regions: North, South, West, East.
#
# 🪄 Initial Name: Frosty Adventure Snow Sled
# 💬 Reflection 1: Frosty Luxe Snow Sled
# 💬 Reflection 2: Frosty Luxe Premium Snow Sled
#
# 🔹 Processing Product ID: T0006 (Regenerate: True)
#
# 📘 product_data for T0006:
# Category: Toys, Avg Price: 54.57, Avg Discount: 10.19%, Common Weather: Rainy, Common Season: Autumn, Holiday/Promotion Frequency: 350, Active Regions: East, North, West, South.
#
# 🪄 Initial Name: Raindrop Adventure Play Tent
# 💬 Reflection 1: Raindrop Haven Play Tent
# 💬 Reflection 2: AutumnRaindrop Fantasy Tent
#
# 🔹 Processing Product ID: C0006 (Regenerate: True)
#
# 📘 product_data for C0006:
# Category: Clothing, Avg Price: 55.71, Avg Discount: 9.89%, Common Weather: Rainy, Common Season: Spring, Holiday/Promotion Frequency: 365, Active Regions: North, South, West, East.
#
# 🪄 Initial Name: AquaGuard Rain Jacket
# 💬 Reflection 1: AquaGuard Spring Shield Jacket
# 💬 Reflection 2: AquaGuard Spring Rain Jacket
#
# 🔹 Processing Product ID: E0004 (Regenerate: True)
#
# 📘 product_data for E0004:
# Category: Electronics, Avg Price: 56.18, Avg Discount: 10.37%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 381, Active Regions: East, North, South, West.
#
# 🪄 Initial Name: LuxeGlow SnowSmart Heater
# 💬 Reflection 1: LuxeGlow Winter Radiance Heater
# 💬 Reflection 2: LuxeGlow Snow Radiance Heater
#
# 🔹 Processing Product ID: G0008 (Regenerate: True)
#
# 📘 product_data for G0008:
# Category: Groceries, Avg Price: 56.45, Avg Discount: 9.71%, Common Weather: Rainy, Common Season: Spring, Holiday/Promotion Frequency: 369, Active Regions: West, South, North, East.
#
# 🪄 Initial Name: RainyDay Harvest Bounty
# 💬 Reflection 1: PureSpring Harvest Medley
# 💬 Reflection 2: PureSpring Rainforest Medley
#
# 🔹 Processing Product ID: T0007 (Regenerate: True)
#
# 📘 product_data for T0007:
# Category: Toys, Avg Price: 53.67, Avg Discount: 10.1%, Common Weather: Snowy, Common Season: Autumn, Holiday/Promotion Frequency: 360, Active Regions: South, North, West, East.
#
# 🪄 Initial Name: Frosty Adventure Snow Sled
# 💬 Reflection 1: Frosty Luxe Snow Sled
# 💬 Reflection 2: Frosty Luxe Winter Sled
#
# 🔹 Processing Product ID: C0011 (Regenerate: True)
#
# 📘 product_data for C0011:
# Category: Clothing, Avg Price: 55.98, Avg Discount: 9.33%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 349, Active Regions: North, West, East, South.
#
# 🪄 Initial Name: Snowdrift Luxe Parka
# 💬 Reflection 1: Snowdrift Luxe Insulated Parka
# 💬 Reflection 2: Snowdrift Luxe Insulated Parka
#
# 🔹 Processing Product ID: G0013 (Regenerate: True)
#
# 📘 product_data for G0013:
# Category: Groceries, Avg Price: 55.11, Avg Discount: 9.84%, Common Weather: Snowy, Common Season: Autumn, Holiday/Promotion Frequency: 379, Active Regions: West, South, North, East.
#
# 🪄 Initial Name: HarvestWinter Spice Blend
# 💬 Reflection 1: PureHarvest Winter Spice Blend
# 💬 Reflection 2: PureHarvest Autumn Spice Medley
#
# 🔹 Processing Product ID: G0014 (Regenerate: True)
#
# 📘 product_data for G0014:
# Category: Groceries, Avg Price: 54.54, Avg Discount: 10.26%, Common Weather: Cloudy, Common Season: Spring, Holiday/Promotion Frequency: 346, Active Regions: West, East, North, South.
#
# 🪄 Initial Name: SpringHarvest Gourmet Blend
# 💬 Reflection 1: SpringHarvest Artisan Grain Medley
# 💬 Reflection 2: SpringHarvest Gourmet Grain Medley
#
# 🔹 Processing Product ID: G0020 (Regenerate: True)
#
# 📘 product_data for G0020:
# Category: Groceries, Avg Price: 54.55, Avg Discount: 10.33%, Common Weather: Rainy, Common Season: Winter, Holiday/Promotion Frequency: 351, Active Regions: South, North, West, East.
#
# 🪄 Initial Name: HarvestMingle Winter Spice Blend
# 💬 Reflection 1: WinterGlow Spice Medley
# 💬 Reflection 2: WinterGlow Spice Blend
#
# 🔹 Processing Product ID: C0001 (Regenerate: True)
#
# 📘 product_data for C0001:
# Category: Clothing, Avg Price: 53.06, Avg Discount: 10.08%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 366, Active Regions: North, West, South, East.
#
# 🪄 Initial Name: Autumn Breeze Cardigan
# 💬 Reflection 1: Luxe Autumn Breeze Knit Cardigan
# 💬 Reflection 2: Luxe Autumn Breeze Knit Cardigan Wrap
#
# 🔹 Processing Product ID: C0004 (Regenerate: True)
#
# 📘 product_data for C0004:
# Category: Clothing, Avg Price: 53.63, Avg Discount: 10.15%, Common Weather: Sunny, Common Season: Winter, Holiday/Promotion Frequency: 374, Active Regions: South, West, East, North.
#
# 🪄 Initial Name: RadiantHaven Winter Wrap
# 💬 Reflection 1: Luxe Winter Wrap Coat
# 💬 Reflection 2: Luxe Cozy Winter Wrap Coat
#
# 🔹 Processing Product ID: E0018 (Regenerate: True)
#
# 📘 product_data for E0018:
# Category: Electronics, Avg Price: 55.55, Avg Discount: 10.28%, Common Weather: Sunny, Common Season: Autumn, Holiday/Promotion Frequency: 403, Active Regions: East, South, West, North.
#
# 🪄 Initial Name: LuxeGlow Portable Solar Charger
# 💬 Reflection 1: LuxeGlow Autumn Solar Power Bank
# 💬 Reflection 2: LuxeGlow Autumn Solar Charger
#
# 🔹 Processing Product ID: G0015 (Regenerate: True)
#
# 📘 product_data for G0015:
# Category: Groceries, Avg Price: 55.32, Avg Discount: 10.1%, Common Weather: Snowy, Common Season: Winter, Holiday/Promotion Frequency: 346, Active Regions: South, East, North, West.
#
# 🪄 Initial Name: FrostedHarvest Gourmet Soup Mix
# 💬 Reflection 1: FrostedHarvest Winter Comfort Soup Mix
# 💬 Reflection 2: FrostedHarvest Cozy Winter Soup Mix
#
# 🔹 Processing Product ID: F0020 (Regenerate: True)
#
# 📘 product_data for F0020:
# Category: Furniture, Avg Price: 57.05, Avg Discount: 9.84%, Common Weather: Snowy, Common Season: Spring, Holiday/Promotion Frequency: 359, Active Regions: East, West, South, North.
#
# 🪄 Initial Name: Frosted Maple Accent Chair
# 💬 Reflection 1: Luxe Frosted Maple Accent Chair
# 💬 Reflection 2: Luxe Frosted Maple Lounge Chair
#
# 🔹 Processing Product ID: F0001 (Regenerate: True)
#
# 📘 product_data for F0001:
# Category: Furniture, Avg Price: 54.52, Avg Discount: 10.08%, Common Weather: Sunny, Common Season: Spring, Holiday/Promotion Frequency: 367, Active Regions: South, North, East, West.
#
# 🪄 Initial Name: SunnySpring Patio Lounge Chair
# 💬 Reflection 1: SunnySpring Luxe Outdoor Lounge Chair
# 💬 Reflection 2: SunnySpring Luxe Patio Lounge Chair
#
# 🔹 Processing Product ID: F0016 (Regenerate: True)
#
# 📘 product_data for F0016:
# Category: Furniture, Avg Price: 55.81, Avg Discount: 9.99%, Common Weather: Rainy, Common Season: Summer, Holiday/Promotion Frequency: 369, Active Regions: West, South, North, East.
#
# 🪄 Initial Name: RainShield Outdoor Lounge Chair
# 💬 Reflection 1: LuxeRain Outdoor Lounge Chair
# 💬 Reflection 2: LuxeRain Summer Lounge Chair
#
# 🔹 Processing Product ID: E0019 (Regenerate: True)
#
# 📘 product_data for E0019:
# Category: Electronics, Avg Price: 53.46, Avg Discount: 10.23%, Common Weather: Snowy, Common Season: Summer, Holiday/Promotion Frequency: 350, Active Regions: West, South, North, East.
#
# 🪄 Initial Name: FrostGuard Wireless Earbuds
# 💬 Reflection 1: FrostGuard Summer Breeze Earbuds
# 💬 Reflection 2: FrostGuard Summer Breeze Wireless Earbuds
#
# ✅ Completed. Finalized names for 100 products.

# %%
product_names_df
# Out:
#    Product ID     Category                              RefinedName_2
# 0       G0001    Groceries   HarvestEssence Summer Cloudberry Delight
# 1       T0002         Toys              Snowy Luxe Plush Sledding Toy
# 2       T0003         Toys                 Autumn Splash Jumper Boots
# 3       T0004         Toys     SunnyQuest Adventure Explorer Backpack
# 4       E0005  Electronics    SunnyWave Luxe Winter Bluetooth Speaker
# ..        ...          ...                                        ...
# 95      G0015    Groceries        FrostedHarvest Cozy Winter Soup Mix
# 96      F0020    Furniture            Luxe Frosted Maple Lounge Chair
# 97      F0001    Furniture        SunnySpring Luxe Patio Lounge Chair
# 98      F0016    Furniture               LuxeRain Summer Lounge Chair
# 99      E0019  Electronics  FrostGuard Summer Breeze Wireless Earbuds
#
# [100 rows x 3 columns]

# %%
# new_df_names = assign_product_names_to_main_df(df_sample, product_names_df)
new_df_names = assign_product_names_to_main_df(df, product_names_df)
new_df_names
# Out:
# ✅ Assigned product names to 73100/73100 rows using Product ID mapping.
# 🧩 New column added: 'Product Name'
#             Date Store ID Product ID     Category Region  Inventory Level  \
# 0     2022-01-01     S001      G0001    Groceries  North              231
# 1     2022-01-01     S001      T0002         Toys  South              204
# 2     2022-01-01     S001      T0003         Toys   West              102
# 3     2022-01-01     S001      T0004         Toys  North              469
# 4     2022-01-01     S001      E0005  Electronics   East              166
# ...          ...      ...        ...          ...    ...              ...
# 73095 2024-01-01     S005      F0016    Furniture   East               96
# 73096 2024-01-01     S005      T0017         Toys  North              313
# 73097 2024-01-01     S005      C0018     Clothing   West              278
# 73098 2024-01-01     S005      T0019         Toys   East              374
# 73099 2024-01-01     S005      G0020    Groceries   East              117
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0             127             55           135.47  33.50        20
# 1             150             66           144.04  63.01        20
# 2              65             51            74.02  27.99        10
# 3              61            164            62.18  32.72        10
# 4              14            135             9.26  73.64         0
# ...           ...            ...              ...    ...       ...
# 73095           8            127            18.46  73.73        20
# 73096          51            101            48.43  82.57        10
# 73097          36            151            39.65  11.11        10
# 73098         264             21           270.52  53.14        20
# 73099           6            165             2.33  78.39        20
#
#       Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality  \
# 0                 Rainy                  0               29.69      Autumn
# 1                 Sunny                  0               66.16      Autumn
# 2                 Sunny                  1               31.32      Summer
# 3                Cloudy                  1               34.74      Autumn
# 4                 Sunny                  0               68.95      Summer
# ...                 ...                ...                 ...         ...
# 73095             Snowy                  0               72.45      Winter
# 73096            Cloudy                  0               83.78      Autumn
# 73097             Rainy                  0               10.91      Winter
# 73098             Rainy                  0               55.80      Spring
# 73099             Rainy                  1               79.52      Spring
#
#       New Product ID                              Product Name
# 0              G0001  HarvestEssence Summer Cloudberry Delight
# 1              T0002             Snowy Luxe Plush Sledding Toy
# 2              T0003                Autumn Splash Jumper Boots
# 3              T0004    SunnyQuest Adventure Explorer Backpack
# 4              E0005   SunnyWave Luxe Winter Bluetooth Speaker
# ...              ...                                       ...
# 73095          F0016              LuxeRain Summer Lounge Chair
# 73096          T0017                NimbusPlay CloudGlide Kite
# 73097          C0018           SnowSprout Luxe Fleece Pullover
# 73098          T0019            CloudPlay Adventure Splash Kit
# 73099          G0020                    WinterGlow Spice Blend
#
# [73100 rows x 17 columns]

# %%
len(new_df_names)
# Out:
# 73100

# %%
# Saving new product names xlsx:
product_name_updated_file = f"op_prod_name_ref_data_test"
save_upd_name_xlsx = save_dataframe_to_xlsx(new_df_names, product_name_updated_file)
# Out:
# File saved successfully → op_prod_name_ref_data_test.xlsx

# %% [markdown]
# ## Categorywise Ads Generation

# %%
# -----------------------------------------------
#  Utility: Category wise context extraction
# -----------------------------------------------

def gather_category_context_with_products(df, product_names_df, category):
    """
    Aggregates contextual data for a given category (from main df) and
    appends all generated product names belonging to that category.
    """

    category = str(category).strip().title()
    sub_df = df[df["Category"].str.strip().str.title() == category].copy()
    if sub_df.empty:
        return ""

    # Category-level stats
    avg_price = round(sub_df["Price"].mean(), 2)
    avg_discount = round(sub_df["Discount"].mean(), 2)
    common_weather = sub_df["Weather Condition"].mode().iloc[0] if not sub_df["Weather Condition"].mode().empty else "Varied"
    common_season = sub_df["Seasonality"].mode().iloc[0] if not sub_df["Seasonality"].mode().empty else "All Seasons"
    holiday_freq_pct = round((sub_df["Holiday/Promotion"].sum() / len(sub_df)) * 100, 2)
    regions = ", ".join(sorted(sub_df["Region"].dropna().unique()))

    # Get all product names for this category
    product_subset = product_names_df[product_names_df["Category"].str.strip().str.title() == category]
    product_names = product_subset["RefinedName_2"].dropna().unique().tolist()
    product_list = ", ".join(product_names[:15])  # limit for prompt brevity

    context = (
        f"Category: {category}\n"
        f"Average Price: ₹{avg_price}\n"
        f"Average Discount: {avg_discount}%\n"
        f"Common Weather: {common_weather}\n"
        f"Common Season: {common_season}\n"
        f"Holiday/Promotion Frequency: {holiday_freq_pct}%\n"
        f"Active Regions: {regions}\n"
        f"Products in this Category: {product_list}"
    )
    return context

# %%
# -----------------------------------------------
#  Utility: Category wise Holoday Ads Generation 
# -----------------------------------------------


# def generate_autonomous_category_ads_with_products(df, product_names_df, category, num_ads=5):
#     """
#     Generates realistic ad campaigns for a category using both the
#     contextual data and actual product names from product_names_df.
#     The LLM infers campaign names, offers, and date ranges automatically.
#     """

#     category_context = gather_category_context_with_products(df, product_names_df, category)
#     if not category_context:
#         print(f"⚠️ No data found for category: {category}")
#         return []

#     prompt = f"""
#     You are a top-tier retail marketing copywriter.

#     Based on the following category and product data,
#     generate multiple realistic advertisement campaigns with seasonal or event-based offers.
#     Each campaign should include a plausible date range.

#     **Category & Product Context:**
#     {category_context}

#     Guidelines:
#     - Infer {num_ads} realistic promotional campaigns for this category.
#     - Invent short date ranges (e.g., “Dec 15 – Jan 05”, “Jul 01 – Jul 15”) matching the tone of the season.
#     - Each advertisement should:
#         • Mention real product names naturally in the copy.
#         • Include an offer (e.g., “up to 40% off” or “Buy 2 Get 1 Free”).
#         • Capture the seasonal tone (festive, fresh, cozy, etc.)
#         • Be 40–90 words, compelling and professional.
#         • Optionally include a CTA (Shop now, Don’t miss out, Limited time offer, etc.)
#     - Output format:
#         1. [Campaign Name] – [Date Range]: [Advertisement Text]
#         2. ...

#     Output only the numbered list.
#     """

#     result = llm.invoke([
#         SystemMessage(content="You are a professional retail marketing strategist."),
#         HumanMessage(content=prompt)
#     ])
#     raw_output = result.content.strip()

#     # Parse structured LLM output
#     ads = []
#     for line in raw_output.split("\n"):
#         if line.strip() and line[0].isdigit():
#             try:
#                 campaign_part, ad_text = line.split(":", 1)
#                 if "–" in campaign_part:
#                     campaign_name, date_range = campaign_part.split("–", 1)
#                 elif "-" in campaign_part:
#                     campaign_name, date_range = campaign_part.split("-", 1)
#                 else:
#                     campaign_name, date_range = campaign_part, ""
                    
#                 ads.append({
#                     "Category": category,
#                     "Campaign": campaign_name.strip(" ."),
#                     "Date Range": date_range.strip(),
#                     "Advertisement": ad_text.strip()
#                 })
#             except ValueError:
#                 continue

#     print(f"✅ Generated {len(ads)} ads for category: {category}")
#     return ads



def generate_single_category_ads(df, product_names_df, category, num_ads=5, max_retries=3):
    """
    Generates a specified number of advertisements for a single category.
    Uses global LLM instance to infer seasonal date ranges, offers, and ad copy automatically.
    Retries if the output is incomplete.
    """

    category_context = gather_category_context_with_products(df, product_names_df, category)
    if not category_context:
        print(f"⚠️ No data found for category: {category}")
        return []

    def _generate_once():
        prompt = f"""
        You are a professional retail marketing strategist and copywriter.

        Based on the following category and product data, create exactly **{num_ads}**
        seasonal or event-based advertisement campaigns.

        **Category & Product Context:**
        {category_context}

        Each campaign must include:
        - Campaign Name
        - Date Range (realistic, e.g., "Dec 10 – Dec 30" or "Jul 01 – Jul 15")
        - Advertisement Text (40–90 words)
        - Natural inclusion of real product names
        - An offer ("up to X% off", "Buy 2 Get 1 Free", etc.)
        - Optional CTA ("Shop now!", "Limited time offer!", etc.)

        The tone should fit the season or context (festive, cozy, refreshing, etc.)
        Avoid repetition between campaigns.

        Output format (exactly {num_ads} items):
        1. [Campaign Name] – [Date Range]: [Advertisement Text]
        2. ...
        """

        result = llm.invoke([
            SystemMessage(content="You are a disciplined and creative retail marketing copywriter."),
            HumanMessage(content=prompt)
        ])
        return result.content.strip()

    retries = 0
    ads = []
    while retries < max_retries:
        raw_output = _generate_once()

        parsed_ads = []
        for match in re.finditer(r"(\d+)\.\s*(.*?)\s*[-–]\s*(.*?):\s*(.*)", raw_output):
            try:
                campaign_name = match.group(2).strip()
                date_range = match.group(3).strip()
                text = match.group(4).strip()
                parsed_ads.append({
                    "Category": category,
                    "Campaign": campaign_name,
                    "Date Range": date_range,
                    "Advertisement": text
                })
            except Exception:
                continue

        ads = parsed_ads
        if len(ads) >= num_ads:
            break

        retries += 1
        print(f"⚠️ [{category}] Only got {len(ads)} ads (target {num_ads}), retrying {retries}/{max_retries}...")
        time.sleep(2)

    print(f"✅ [{category}] Generated {len(ads)} ads successfully.")
    return ads



def generate_all_category_ads(df, product_names_df, num_ads_per_category=5):
    """
    Generates multiple ads for all unique categories found in product_names_df.
    Returns a combined DataFrame only — does not save to disk.
    """

    all_ads = []
    categories = sorted(product_names_df["Category"].dropna().unique().tolist())
    print(f"\n🧩 Found {len(categories)} unique categories.")

    for cat in categories:
        print(f"\n🪧 Generating {num_ads_per_category} ads for category: {cat}")
        ads = generate_single_category_ads(
            df=df,
            product_names_df=product_names_df,
            category=cat,
            num_ads=num_ads_per_category
        )
        all_ads.extend(ads)

    ads_df = pd.DataFrame(all_ads)
    print(f"\n📊 Total ads generated: {len(ads_df)} across {len(categories)} categories.")
    return ads_df

# %%
# Generate all ads
ads_df = generate_all_category_ads(
    df=df,
    product_names_df=product_names_df,
    num_ads_per_category=12
)
# Out:
# 🧩 Found 5 unique categories.
#
# 🪧 Generating 12 ads for category: Clothing
# ✅ [Clothing] Generated 12 ads successfully.
#
# 🪧 Generating 12 ads for category: Electronics
# ✅ [Electronics] Generated 12 ads successfully.
#
# 🪧 Generating 12 ads for category: Furniture
# ✅ [Furniture] Generated 12 ads successfully.
#
# 🪧 Generating 12 ads for category: Groceries
# ✅ [Groceries] Generated 12 ads successfully.
#
# 🪧 Generating 12 ads for category: Toys
# ✅ [Toys] Generated 12 ads successfully.
#
# 📊 Total ads generated: 60 across 5 categories.

# %%
# Inspect ads
ads_df.head()
# Out:
#    Category                      Campaign       Date Range  \
# 0  Clothing    **Winter Wonderland Sale**  Dec 01 – Dec 15
# 1  Clothing    **Festive Fashion Frenzy**  Dec 16 – Dec 26
# 2  Clothing    **New Year, New Wardrobe**  Dec 27 – Jan 10
# 3  Clothing  **Cozy Comforts Collection**  Jan 11 – Jan 25
# 4  Clothing       **Spring Refresh Sale**  Feb 01 – Feb 14
#
#                                        Advertisement
# 0  Embrace the chill with our Winter Wonderland S...
# 1  Celebrate the season with our Festive Fashion ...
# 2  Kickstart the New Year with a fresh wardrobe! ...
# 3  Dive into the Cozy Comforts Collection! Snuggl...
# 4  Welcome spring with open arms! Refresh your wa...

# %%
# Save ads:
final_ads_file_name = f"category_ads_with_products_2"
final_save = save_dataframe_to_xlsx(ads_df, final_ads_file_name)
print(final_save)
# Out:
# File saved successfully → category_ads_with_products_2.xlsx
# category_ads_with_products_2.xlsx

# %%
ads_df.iloc[0]["Advertisement"]
# Out:
# 'Embrace the chill with our Winter Wonderland Sale! Wrap yourself in style with the Luxe Cloudspire Winter Wrap Coat or the Luxe Cozy Autumn Cardigan. Enjoy a warm discount of up to 20% off on selected items. Don’t miss this chance to elevate your winter wardrobe! Shop now!'

# %%
ads_df["holiday_ad_content"] = ads_df.apply( lambda row: f"{row['Campaign']}\t{row['Date Range']}\n{row['Advertisement']}", axis=1 )

print(ads_df.iloc[10])
# Out:
# Category                                                       Clothing
# Campaign                                       **Back to School Style**
# Date Range                                              Jul 01 – Jul 15
# Advertisement         Gear up for a stylish school year! Discover co...
# holiday_ad_content    **Back to School Style**\tJul 01 – Jul 15\nGea...
# Name: 10, dtype: object

# %%
final_ads_file_name = f"final_categ_ads_products_data"  # f"category_ads_with_products_3"
final_save = save_dataframe_to_xlsx(ads_df, final_ads_file_name)
print(final_save)
# Out:
# File saved successfully → final_categ_ads_products_data.xlsx
# final_categ_ads_products_data.xlsx

# %%
print(ads_df.iloc[2])
# Out:
# Category                                                       Clothing
# Campaign                                     **New Year, New Wardrobe**
# Date Range                                              Dec 27 – Jan 10
# Advertisement         Kickstart the New Year with a fresh wardrobe! ...
# holiday_ad_content    **New Year, New Wardrobe**\tDec 27 – Jan 10\nK...
# Name: 2, dtype: object
